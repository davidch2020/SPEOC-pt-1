# %% [markdown]
# Aggregating the following files: DE, MA, NH, NJ, NY, Pierce
#
# Column order (copy and pasted from david):
#  - letter
#  - date of the certificate | month
#  - date of the certificate | day
#  - date of the certificate | year
#  - to whom due | first name
#  - to whom due | last name
#  - to whom due | title
#  - to whom due | first name.1
#  - to whom due | last name.1
#  - to whom due | title.1
#  - time when the debt became due | month
#  - time when the debt became due | day
#  - time when the debt became due | year
#  - amount | dollars
#  - amount | 90th
#  - line strike thorugh? | yes?
#  - line strike thorugh? | note
#  - notes
#  - state

# %%
#IMPORTS
import pandas as pd
import numpy as np

# %%
#Helpers
def deNaN(series):
    """
    amends pandas series by replacing NaN values with empty strings
    :param series: pandas series
    """

    return series.apply(lambda x: "" if type(x) != str else x)
oii = 0 #keeps track of the org_index
def add_org_index(series: pd.Series):
    global oii
    series.index
    series["org_index"] = oii
    oii = oii + 1
    return series

# %%
nj = pd.read_excel("../../data_raw/pre1790/liquidated_debt_certificates_NJ.xlsx")
nj = nj[10:5117].drop(columns=["Record Name", "Records of the New Jersey Continental Loan Office, 1777-1790", "Unnamed: 19"])

cols = {"Unnamed: 2": "letter", 
        "Unnamed: 3": "date of the certificate | month",
        "Unnamed: 4": "date of the certificate | day",
        "Unnamed: 5": "date of the certificate | year",
        "Unnamed: 6": "to whom due | title",
        "Unnamed: 7": "to whom due | first name",
        "Unnamed: 8": "to whom due | last name",
        "Unnamed: 9": "to whom due | title.1",
        "F": "to whom due | first name.1",
        "Unnamed: 11": "to whom due | last name.1",
        "Unnamed: 12": "time when the debt became due | day",
        "Unnamed: 13": "time when the debt became due | month",
        "Unnamed: 14": "time when the debt became due | year",
        "Unnamed: 15": "amount | dollars",
        "Unnamed: 16": "amount | 90th",
        "Unnamed: 17": "line strike through? | note",
        "Unnamed: 18": "notes"
}

nj = nj.rename(columns=cols)
nj['state'] = 'nj'
nj["line strike through? | yes?"] = 0 # add line strike through column
# line strike through binary col to 1 if note is present, 0 if note is not present
def add_strike_conf(series: pd.Series):
    if str(series["line strike through? | note"]) != "nan": #For some reason this means Nan
        series["line strike through? | yes?"] = 1
    else:
        series["line strike through? | yes?"] = ""
    return series
nj = nj.apply(add_strike_conf, axis=1)
nj['org_file'] = "liquidated_debt_certificates_NJ.xlsx"
nj["org_index"] = 0
oii = 0
nj = nj.apply(add_org_index, axis=1)
nj
# Out:
#      letter  date of the certificate | month  date of the certificate | day  \
# 10        G                               12                             23
# 11        A                               12                             23
# 12        H                               12                             23
# 13        R                               12                             23
# 14        H                               12                             23
# ...     ...                              ...                            ...
# 5112      H                               12                             27
# 5113      A                               12                             27
# 5114      A                               12                             27
# 5115      H                               12                             27
# 5116      A                               12                             27
#
#       date of the certificate | year to whom due | title  \
# 10                              1783                 NaN
# 11                              1783                 NaN
# 12                              1783                 NaN
# 13                              1783                 NaN
# 14                              1783                 NaN
# ...                              ...                 ...
# 5112                            1786                 NaN
# 5113                            1786                 NaN
# 5114                            1786                 NaN
# 5115                            1786                 NaN
# 5116                            1786                 NaN
#
#      to whom due | first name to whom due | last name  to whom due | title.1  \
# 10                     Joseph                  Milnor                    NaN
# 11                     Joseph                  Milnor                    NaN
# 12                     Joseph                  Milnor                    NaN
# 13              Furman & Hunt                     NaN                    NaN
# 14              Furman & Hunt                     NaN                    NaN
# ...                       ...                     ...                    ...
# 5112                    Henry                   Nagle                    NaN
# 5113                    Peter                Demarest                    NaN
# 5114                     John                Orriancy                    NaN
# 5115                    Peter               Wanamaker                    NaN
# 5116                  Richard               Wanamaker                    NaN
#
#      to whom due | first name.1 to whom due | last name.1  ...  \
# 10                          NaN                       NaN  ...
# 11                          NaN                       NaN  ...
# 12                          NaN                       NaN  ...
# 13                          NaN                       NaN  ...
# 14                          NaN                       NaN  ...
# ...                         ...                       ...  ...
# 5112                        NaN                       NaN  ...
# 5113                        NaN                       NaN  ...
# 5114                        NaN                       NaN  ...
# 5115                        NaN                       NaN  ...
# 5116                        NaN                       NaN  ...
#
#       time when the debt became due | month  \
# 10                                      1.0
# 11                                      1.0
# 12                                      1.0
# 13                                     15.0
# 14                                     30.0
# ...                                     ...
# 5112                                    8.0
# 5113                                    7.0
# 5114                                    7.0
# 5115                                    7.0
# 5116                                    7.0
#
#       time when the debt became due | year  amount | dollars  amount | 90th  \
# 10                                  1782.0             217.0           15.0
# 11                                  1781.0            1108.0           60.0
# 12                                  1780.0             339.0            6.0
# 13                                  1780.0             146.0           66.0
# 14                                  1780.0             277.0           48.0
# ...                                    ...               ...            ...
# 5112                                1778.0               5.0           21.0
# 5113                                1778.0               5.0           54.0
# 5114                                1778.0               8.0           54.0
# 5115                                1779.0               5.0           72.0
# 5116                                1779.0               4.0           85.0
#
#       line strike through? | note notes state line strike through? | yes?  \
# 10                        Lo 44.1   NaN    nj                           1
# 11                       Lo 115.2   NaN    nj                           1
# 12                       Lo 115.2   NaN    nj                           1
# 13                        Lo 44.1   NaN    nj                           1
# 14                        Lo 44.1   NaN    nj                           1
# ...                           ...   ...   ...                         ...
# 5112                          441   NaN    nj                           1
# 5113                        N 110   NaN    nj                           1
# 5114                          NaN   NaN    nj
# 5115                          362   NaN    nj                           1
# 5116                          531   NaN    nj                           1
#
#                                   org_file org_index
# 10    liquidated_debt_certificates_NJ.xlsx         0
# 11    liquidated_debt_certificates_NJ.xlsx         1
# 12    liquidated_debt_certificates_NJ.xlsx         2
# 13    liquidated_debt_certificates_NJ.xlsx         3
# 14    liquidated_debt_certificates_NJ.xlsx         4
# ...                                    ...       ...
# 5112  liquidated_debt_certificates_NJ.xlsx      5102
# 5113  liquidated_debt_certificates_NJ.xlsx      5103
# 5114  liquidated_debt_certificates_NJ.xlsx      5104
# 5115  liquidated_debt_certificates_NJ.xlsx      5105
# 5116  liquidated_debt_certificates_NJ.xlsx      5106
#
# [5107 rows x 21 columns]

# %%
nh = pd.read_excel("../../data_raw/pre1790/liquidated_debt_certificates_NH.xlsx")
nh = nh[11:189].drop(columns=["Record Name", "Records of the Connecticut, New Hampshire, and Rhode Island Continental Loan Office, 1777-1789", "Unnamed: 2"])

cols = {"Unnamed: 3": "letter", 
        "Unnamed: 4": "date of the certificate | month",
        "Unnamed: 5": "date of the certificate | day",
        "Unnamed: 6": "date of the certificate | year",
        "Unnamed: 7": "to whom due | first name",
        "Unnamed: 8": "to whom due | last name",
        "Unnamed: 9": "to whom due | title",
        "Unnamed: 10": "time when the debt became due | month",
        "Unnamed: 11": "time when the debt became due | day",
        "Unnamed: 12": "time when the debt became due | year",
        "Unnamed: 13": "amount | dollars",
        "Unnamed: 14": "amount | 90th",
        "Unnamed: 15": "line strike through? | yes?",
        "Unnamed: 16": "line strike through? | note",
        "Unnamed: 17": "notes"
}

nh = nh.rename(columns=cols)
nh['state'] = 'nh'
nh['org_file'] = "liquidated_debt_certificates_NH.xlsx"
nh["org_index"] = 0
oii = 0
nh = nh.apply(add_org_index, axis=1)
nh["to whom due | title.1"] = ""
nh["to whom due | first name.1"] = ""
nh["to whom due | last name.1"] = ""
nh
# Out:
# /Users/liamloughead/Code/SPEOC-pt-1/.venv/lib/python3.11/site-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
#     letter  date of the certificate | month  date of the certificate | day  \
# 11       C                                8                             27
# 12       L                                8                             27
# 13       G                                8                             27
# 14       C                                9                              2
# 15       B                                9                              2
# ..     ...                              ...                            ...
# 184      I                                3                              7
# 185      L                                3                              9
# 186      N                                3                              9
# 187      P                                3                             16
# 188      R                                3                             16
#
#      date of the certificate | year to whom due | first name  \
# 11                             1783                Elizabeth
# 12                             1783                   Joshua
# 13                             1783                   Joshua
# 14                             1783                 Phillips
# 15                             1783                  William
# ..                              ...                      ...
# 184                            1786                   Samuel
# 185                            1786                    Sarah
# 186                            1786                  Richard
# 187                            1786                   Joseph
# 188                            1786                   Joseph
#
#     to whom due | last name to whom due | title  \
# 11                   Lowell                 NaN
# 12                 Brackett                 Jun
# 13                 Brackett                 NaN
# 14                    White                 Esq
# 15                    White                 NaN
# ..                      ...                 ...
# 184                   Odlin                 NaN
# 185                 Simpson                 Mrs
# 186                Bartlett                 Esq
# 187                 Boynton                  Lt
# 188                 Pearson                 Esq
#
#      time when the debt became due | month  \
# 11                                       4
# 12                                       4
# 13                                       4
# 14                                       4
# 15                                       4
# ..                                     ...
# 184                                      4
# 185                                      4
# 186                                      4
# 187                                     11
# 188                                      4
#
#      time when the debt became due | day  \
# 11                                    16
# 12                                    16
# 13                                    16
# 14                                    16
# 15                                    16
# ..                                   ...
# 184                                   16
# 185                                   16
# 186                                   16
# 187                                    1
# 188                                   16
#
#      time when the debt became due | year  ...  amount | 90th  \
# 11                                   1782  ...           45.0
# 12                                   1782  ...            NaN
# 13                                   1782  ...           45.0
# 14                                   1782  ...           67.0
# 15                                   1782  ...           45.0
# ..                                    ...  ...            ...
# 184                                  1782  ...           22.0
# 185                                  1782  ...           45.0
# 186                                  1782  ...           67.0
# 187                                  1779  ...           57.0
# 188                                  1782  ...           22.0
#
#      line strike through? | yes?  line strike through? | note notes state  \
# 11                           1.0                      1059.16   NaN    nh
# 12                           1.0                          558   NaN    nh
# 13                           1.0                     20.59.16   NaN    nh
# 14                           1.0                          558   NaN    nh
# 15                           1.0                          933   NaN    nh
# ..                           ...                          ...   ...   ...
# 184                          1.0                   LO 102.107   NaN    nh
# 185                          1.0                   LO 197.206   NaN    nh
# 186                          1.0                         1100   NaN    nh
# 187                          1.0                           RO   NaN    nh
# 188                          1.0                         5121   NaN    nh
#
#                                  org_file org_index  to whom due | title.1  \
# 11   liquidated_debt_certificates_NH.xlsx         0
# 12   liquidated_debt_certificates_NH.xlsx         1
# 13   liquidated_debt_certificates_NH.xlsx         2
# 14   liquidated_debt_certificates_NH.xlsx         3
# 15   liquidated_debt_certificates_NH.xlsx         4
# ..                                    ...       ...                    ...
# 184  liquidated_debt_certificates_NH.xlsx       173
# 185  liquidated_debt_certificates_NH.xlsx       174
# 186  liquidated_debt_certificates_NH.xlsx       175
# 187  liquidated_debt_certificates_NH.xlsx       176
# 188  liquidated_debt_certificates_NH.xlsx       177
#
#     to whom due | first name.1 to whom due | last name.1
# 11
# 12
# 13
# 14
# 15
# ..                         ...                       ...
# 184
# 185
# 186
# 187
# 188
#
# [178 rows x 21 columns]

# %%
ny = pd.read_excel("../../data_raw/pre1790/liquidated_debt_certificates_NY.xlsx")
ny = ny[11:7319].drop(columns=["Record Name", "Records of the New Jersey and New York Continental Loan Offices 1777-1790", "Unnamed: 2"])

cols = {"Unnamed: 3": "letter", 
        "Unnamed: 4": "date of the certificate | month",
        "Unnamed: 5": "date of the certificate | day",
        "Unnamed: 6": "date of the certificate | year",
        "Unnamed: 7": "to whom due | first name",
        "Unnamed: 8": "to whom due | last name",
        "Unnamed: 9": "to whom due | title",
        "Unnamed: 10": "to whom due | first name.1",
        "Unnamed: 11": "to whom due | last name.1",
        "Unnamed: 12": "to whom due | title.1",
        "Unnamed: 13": "time when the debt became due | month",
        "Unnamed: 14": "time when the debt became due | day",
        "Unnamed: 15": "time when the debt became due | year",
        "Unnamed: 16": "amount | dollars",
        "Unnamed: 17": "amount | 90th",
        "Unnamed: 18": "line strike through? | yes?",
        "Unnamed: 19": "line strike through? | note",
        "Unnamed: 20": "notes"
}

ny = ny.rename(columns=cols)
ny['org_file'] = "liquidated_debt_certificates_NY.xlsx"
ny["org_index"] = 0
oii = 0
ny = ny.apply(add_org_index, axis=1)
ny['state'] = 'ny'
ny
# Out:
#      letter  date of the certificate | month  date of the certificate | day  \
# 11        A                                2                             20
# 12        B                                2                             20
# 13        C                                2                             20
# 14        D                                2                             20
# 15        E                                2                             20
# ...     ...                              ...                            ...
# 7314      E                                3                             30
# 7315      G                                3                             31
# 7316      A                                3                             31
# 7317      B                                3                             31
# 7318      C                                3                             31
#
#       date of the certificate | year to whom due | first name  \
# 11                              1784                     John
# 12                              1784                  Mathias
# 13                              1784                     Seth
# 14                              1784                    James
# 15                              1784                   Israel
# ...                              ...                      ...
# 7314                            1787                   Edward
# 7315                            1787                 Susannah
# 7316                            1787                    Jacob
# 7317                            1787                     John
# 7318                            1787                   Luther
#
#      to whom due | last name to whom due | title to whom due | first name.1  \
# 11                    Newkuk                 NaN                        NaN
# 12                    Teller                 NaN                        NaN
# 13                    Marvin                 NaN                        NaN
# 14                  Gallaway                 NaN                        NaN
# 15                    Rogers                 NaN                        NaN
# ...                      ...                 ...                        ...
# 7314                   Lyons                 NaN                        NaN
# 7315                     Dey                 NaN                        NaN
# 7316                   Moore                 NaN                        NaN
# 7317                   Myers                 NaN                        NaN
# 7318                  Halsey                 NaN                        NaN
#
#      to whom due | last name.1  to whom due | title.1  ...  \
# 11                         NaN                    NaN  ...
# 12                         NaN                    NaN  ...
# 13                         NaN                    NaN  ...
# 14                         NaN                    NaN  ...
# 15                         NaN                    NaN  ...
# ...                        ...                    ...  ...
# 7314                       NaN                    NaN  ...
# 7315                       NaN                    NaN  ...
# 7316                       NaN                    NaN  ...
# 7317                       NaN                    NaN  ...
# 7318                       NaN                    NaN  ...
#
#       time when the debt became due | day  \
# 11                                   20.0
# 12                                   11.0
# 13                                   14.0
# 14                                   31.0
# 15                                   17.0
# ...                                   ...
# 7314                                  1.0
# 7315                                  1.0
# 7316                                  1.0
# 7317                                  1.0
# 7318                                  1.0
#
#       time when the debt became due | year amount | dollars  amount | 90th  \
# 11                                    1780              2.0            NaN
# 12                                    1780              8.0             87
# 13                                    1780             18.0            NaN
# 14                                    1780             28.0             80
# 15                                    1780             15.0            NaN
# ...                                    ...              ...            ...
# 7314                                  1780            579.0             33
# 7315                                  1777            210.0            NaN
# 7316                                  1777            582.0             45
# 7317                                  1777            219.0             33
# 7318                                  1777             39.0             52
#
#      line strike through? | yes?  line strike through? | note notes  \
# 11                           NaN                          NaN   NaN
# 12                           NaN                           Ro   NaN
# 13                           NaN                          W10   NaN
# 14                           NaN                          749   NaN
# 15                           NaN                          755   NaN
# ...                          ...                          ...   ...
# 7314                         1.0                           RO   NaN
# 7315                         1.0                          459   NaN
# 7316                         1.0                          441   NaN
# 7317                         1.0                          668   NaN
# 7318                         1.0                          589   NaN
#
#                                   org_file org_index  state
# 11    liquidated_debt_certificates_NY.xlsx         0     ny
# 12    liquidated_debt_certificates_NY.xlsx         1     ny
# 13    liquidated_debt_certificates_NY.xlsx         2     ny
# 14    liquidated_debt_certificates_NY.xlsx         3     ny
# 15    liquidated_debt_certificates_NY.xlsx         4     ny
# ...                                    ...       ...    ...
# 7314  liquidated_debt_certificates_NY.xlsx      7303     ny
# 7315  liquidated_debt_certificates_NY.xlsx      7304     ny
# 7316  liquidated_debt_certificates_NY.xlsx      7305     ny
# 7317  liquidated_debt_certificates_NY.xlsx      7306     ny
# 7318  liquidated_debt_certificates_NY.xlsx      7307     ny
#
# [7308 rows x 21 columns]

# %%
de = pd.read_excel("../../data_raw/pre1790/liquidated_debt_certificates_DE.xlsx")
de = de[11:636].drop(columns=["Record Name", 
    "Mr Paterson remarks that the certificate No. 57 says interest payable from the 1st of March 1780 instead of 1st May 1780, 123 From the 1st of January 1780 instead of 14th January, 234 is in the name of James James    John James"])

cols = {"Unnamed: 2": "letter", 
        "Unnamed: 3": "date of the certificate | day",
        "Unnamed: 4": "date of the certificate | month",
        "Unnamed: 5": "date of the certificate | year",
        "Unnamed: 6": "to whom due | title",
        "Unnamed: 7": "to whom due | first name",
        "Unnamed: 8": "to whom due | last name",
        "Unnamed: 9": "time when the debt became due | day",
        "Unnamed: 10": "time when the debt became due | month",
        "Unnamed: 11": "time when the debt became due | year",
        "Unnamed: 12": "amount | dollars",
        "Unnamed: 13": "amount | 90th",
        "Unnamed: 14": "line strike through? | note",
        "Unnamed: 15": "notes"
}

de = de.rename(columns=cols)
de['state'] = 'de'
de["to whom due | title.1"] = ""
de["to whom due | first name.1"] = ""
de["to whom due | last name.1"] = ""
de['org_file'] = "liquidated_debt_certificates_DE.xlsx"
de["org_index"] = 0
oii = 0
de = de.apply(add_org_index, axis=1)
de["line strike through? | yes?"] = 0 # add line strike through column
# line strike through binary col to 1 if note is present, 0 if note is not present
def add_strike_conf(series: pd.Series):
    if str(series["line strike through? | note"]) != "nan": #For some reason this means Nan
        series["line strike through? | yes?"] = 1
    else:
        series["line strike through? | yes?"] = ""
    return series
de = de.apply(add_strike_conf, axis=1)
de
# Out:
#     letter  date of the certificate | day  date of the certificate | month  \
# 11       B                             18                                3
# 12       C                              1                                4
# 13       H                              1                                4
# 14       J                              1                                4
# 15       L                              1                                4
# ..     ...                            ...                              ...
# 631      N                             18                                1
# 632      P                             18                                1
# 633      R                             20                                1
# 634      E                             20                                1
# 635      G                             20                                1
#
#      date of the certificate | year to whom due | title  \
# 11                             1784                 NaN
# 12                             1784                 NaN
# 13                             1784                 NaN
# 14                             1784                 NaN
# 15                             1784                 NaN
# ..                              ...                 ...
# 631                            1787                 NaN
# 632                            1787                 NaN
# 633                            1787                 NaN
# 634                            1787                 NaN
# 635                            1787                 NaN
#
#     to whom due | first name to whom due | last name  \
# 11                      John                Coppage
# 12                    Joseph                  Harper
# 13                     David                  Harper
# 14                     James                 Coakley
# 15                     James                 Coakley
# ..                       ...                     ...
# 631                   George                Reynolds
# 632                   Samuel                    Enus
# 633                    James                McCorkel
# 634                     John                  Lewden
# 635                     John                 Jamison
#
#      time when the debt became due | day  \
# 11                                  15.0
# 12                                  14.0
# 13                                  10.0
# 14                                  15.0
# 15                                  15.0
# ..                                   ...
# 631                                  1.0
# 632                                  1.0
# 633                                  1.0
# 634                                 13.0
# 635                                  7.0
#
#      time when the debt became due | month  \
# 11                                     2.0
# 12                                    12.0
# 13                                     2.0
# 14                                     3.0
# 15                                     3.0
# ..                                     ...
# 631                                   11.0
# 632                                    7.0
# 633                                    8.0
# 634                                    1.0
# 635                                    9.0
#
#      time when the debt became due | year  ...  amount | 90th  \
# 11                                 1780.0  ...           30.0
# 12                                 1779.0  ...           30.0
# 13                                 1780.0  ...           55.0
# 14                                 1780.0  ...            NaN
# 15                                 1780.0  ...            NaN
# ..                                    ...  ...            ...
# 631                                1783.0  ...            NaN
# 632                                1782.0  ...           30.0
# 633                                1780.0  ...            NaN
# 634                                1780.0  ...           51.0
# 635                                1777.0  ...           60.0
#
#      line strike through? | note notes state to whom due | title.1  \
# 11                          1559   NaN    de
# 12                          4148   NaN    de
# 13                           NaN   NaN    de
# 14                           764   NaN    de
# 15                           764   NaN    de
# ..                           ...   ...   ...                   ...
# 631                         1322   NaN    de
# 632                          NaN   NaN    de
# 633                           RO   NaN    de
# 634                          757   NaN    de
# 635                         1324   NaN    de
#
#     to whom due | first name.1 to whom due | last name.1  \
# 11
# 12
# 13
# 14
# 15
# ..                         ...                       ...
# 631
# 632
# 633
# 634
# 635
#
#                                  org_file org_index  \
# 11   liquidated_debt_certificates_DE.xlsx         0
# 12   liquidated_debt_certificates_DE.xlsx         1
# 13   liquidated_debt_certificates_DE.xlsx         2
# 14   liquidated_debt_certificates_DE.xlsx         3
# 15   liquidated_debt_certificates_DE.xlsx         4
# ..                                    ...       ...
# 631  liquidated_debt_certificates_DE.xlsx       620
# 632  liquidated_debt_certificates_DE.xlsx       621
# 633  liquidated_debt_certificates_DE.xlsx       622
# 634  liquidated_debt_certificates_DE.xlsx       623
# 635  liquidated_debt_certificates_DE.xlsx       624
#
#      line strike through? | yes?
# 11                             1
# 12                             1
# 13
# 14                             1
# 15                             1
# ..                           ...
# 631                            1
# 632
# 633                            1
# 634                            1
# 635                            1
#
# [625 rows x 21 columns]

# %%
ma = pd.read_excel("../../data_raw/pre1790/liquidated_debt_certificates_MA.xlsx")
ma = ma[11:2089].drop(columns=["Record Name", "Records of the Massachusetts Continental Loan Office, 1777-1791", "Unnamed: 2", "Unnamed: 20"])

cols = {"Unnamed: 3": "letter", 
        "Unnamed: 4": "date of the certificate | month",
        "Unnamed: 5": "date of the certificate | day",
        "Unnamed: 6": "date of the certificate | year",
        "Unnamed: 7": "to whom due | first name",
        "Unnamed: 8": "to whom due | last name",
        "Unnamed: 9": "to whom due | title",
        "Unnamed: 10": "to whom due | first name.1",
        "Unnamed: 11": "to whom due | last name.1",
        "Unnamed: 12": "to whom due | title.1",
        "Unnamed: 13": "time when the debt became due | month",
        "Unnamed: 14": "time when the debt became due | day",
        "Unnamed: 15": "time when the debt became due | year",
        "Unnamed: 16": "amount | dollars",
        "Unnamed: 17": "amount | 90th",
        "Unnamed: 18": "line strike through? | note",
        "Unnamed: 19": "notes"
}

ma = ma.rename(columns=cols)
ma['state'] = 'ma'
ma["line strike through? | yes?"] = 0 # add line strike through column
ma['org_file'] = "liquidated_debt_certificates_MA.xlsx"
ma["org_index"] = 0
oii = 0
ma = ma.apply(add_org_index, axis=1)
# line strike through binary col to 1 if note is present, 0 if note is not present
def add_strike_conf(series: pd.Series):
    if str(series["line strike through? | note"]) != "nan": #For some reason this means Nan
        series["line strike through? | yes?"] = 1
    else:
        series["line strike through? | yes?"] = ""
    return series
ma = ma.apply(add_strike_conf, axis=1)
ma
# Out:
# /Users/liamloughead/Code/SPEOC-pt-1/.venv/lib/python3.11/site-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
#      letter  date of the certificate | month  date of the certificate | day  \
# 11        A                                8                              8
# 12        B                                8                              8
# 13        C                                8                              9
# 14        D                                8                             11
# 15        E                                8                             11
# ...     ...                              ...                            ...
# 2084      L                               12                             18
# 2085      H                               12                             18
# 2086      L                               12                             18
# 2087      H                               12                             18
# 2088      I                               12                             18
#
#       date of the certificate | year      to whom due | first name  \
# 11                              1783                         Isaac
# 12                              1783                      Benjamin
# 13                              1783                      Ebenezer
# 14                              1783                         Isaac
# 15                              1783                         Abner
# ...                              ...                           ...
# 2084                            1786  Estate of Capt John Williams
# 2085                            1786                        Ensign
# 2086                            1786                         Benja
# 2087                            1786                          John
# 2088                            1786                      Henry H.
#
#      to whom due | last name to whom due | title to whom due | first name.1  \
# 11                    Peirce                 NaN                        NaN
# 12                    Burley                 NaN                        NaN
# 13                      Clap                 NaN                        NaN
# 14                 Greenwood                 NaN                        NaN
# 15                     Bacon                 NaN                        NaN
# ...                      ...                 ...                        ...
# 2084                     NaN                 NaN                        NaN
# 2085                  Tapper                 NaN                        NaN
# 2086               Kittredge                 NaN                        NaN
# 2087                 Stearns                 NaN                        NaN
# 2088                Williams                 NaN                        NaN
#
#      to whom due | last name.1  to whom due | title.1  ...  \
# 11                         NaN                    NaN  ...
# 12                         NaN                    NaN  ...
# 13                         NaN                    NaN  ...
# 14                         NaN                    NaN  ...
# 15                         NaN                    NaN  ...
# ...                        ...                    ...  ...
# 2084                       NaN                    NaN  ...
# 2085                       NaN                    NaN  ...
# 2086                       NaN                    NaN  ...
# 2087                       NaN                    NaN  ...
# 2088                       NaN                    NaN  ...
#
#       time when the debt became due | day  \
# 11                                     30
# 12                                      1
# 13                                      1
# 14                                      9
# 15                                     27
# ...                                   ...
# 2084                                    3
# 2085                                    1
# 2086                                    1
# 2087                                    1
# 2088                                    1
#
#       time when the debt became due | year  amount | dollars  amount | 90th  \
# 11                                    1782              11.0            NaN
# 12                                    1781             167.0            NaN
# 13                                    1776             373.0            NaN
# 14                                    1780               5.0           16.0
# 15                                    1779               2.0           26.0
# ...                                    ...               ...            ...
# 2084                                  1776             146.0           60.0
# 2085                                  1780              93.0           75.0
# 2086                                  1775              51.0           22.0
# 2087                                  1781              63.0           75.0
# 2088                                  1776             512.0           15.0
#
#       line strike through? | note notes state line strike through? | yes?  \
# 11                            N47   NaN    ma                           1
# 12                            N47   NaN    ma                           1
# 13                            370   NaN    ma                           1
# 14                      Lo 38,263   NaN    ma                           1
# 15                            NaN   NaN    ma
# ...                           ...   ...   ...                         ...
# 2084                    Lo 89,659   NaN    ma                           1
# 2085                      Ro 5340   NaN    ma                           1
# 2086                  Lo 119,1220   NaN    ma                           1
# 2087                           32   NaN    ma                           1
# 2088                    Lo 73,426   NaN    ma                           1
#
#                                   org_file org_index
# 11    liquidated_debt_certificates_MA.xlsx         0
# 12    liquidated_debt_certificates_MA.xlsx         1
# 13    liquidated_debt_certificates_MA.xlsx         2
# 14    liquidated_debt_certificates_MA.xlsx         3
# 15    liquidated_debt_certificates_MA.xlsx         4
# ...                                    ...       ...
# 2084  liquidated_debt_certificates_MA.xlsx      2073
# 2085  liquidated_debt_certificates_MA.xlsx      2074
# 2086  liquidated_debt_certificates_MA.xlsx      2075
# 2087  liquidated_debt_certificates_MA.xlsx      2076
# 2088  liquidated_debt_certificates_MA.xlsx      2077
#
# [2078 rows x 21 columns]

# %%
pierce = pd.read_excel("../../data_raw/pre1790/Pierce_Certs_cleaned_2019.xlsx")
pierce = pierce[1:93308].drop(columns=["CN", "Group", "To Whom Issued", "Officer"])
#pierce = pierce[1:100].drop(columns=["CN", "Group", "To Whom Issued", "Officer"])

cols = {"First": "to whom due | first name",
        "Last": "to whom due | last name",
        "Value": "amount | dollars",
        "State": "state"
}

add_cols = ["letter", "date of the certificate | month", "date of the certificate | day",
            "date of the certificate | year", "to whom due | title", "to whom due | title.1",
            "to whom due | first name.1", "to whom due | last name.1",
            "time when the debt became due | day", "time when the debt became due | month",
            "time when the debt became due | year", "amount | 90th", "line strike through? | note",
            "notes"]

pierce['org_file'] = "Pierce_Certs_cleaned_2019.xlsx"
pierce["org_index"] = 0
oii = 0
pierce = pierce.apply(add_org_index, axis=1)

pierce = pierce.rename(columns=cols)
# line strike through binary col to 1 if note is present, 0 if note is not present
def lowercase_state_abbr(series: pd.Series):
    if str(series["state"]) != "nan": #For some reason this means NaN
        series["state"] = str.lower(series["state"])
    return series
pierce = pierce.apply(lowercase_state_abbr, axis=1)
for col in add_cols:
        pierce[col] = ""
pierce["line strike through? | yes?"] = "" # add line strike through column
pierce
# Out:
#       to whom due | first name to whom due | last name  amount | dollars  \
# 1                         Abbe                   Mason             20.58
# 2                        Abbee                    John             19.38
# 3                        Abbee                    John             13.30
# 4                        Abbet                 Richard             44.66
# 5                       Abbett                  Reuben             80.00
# ...                        ...                     ...               ...
# 93303                     True                   Henry             21.65
# 93304                     True                   Nero              15.05
# 93305                     True                 Zebulon             20.78
# 93306                     True                 Zebulon             53.30
# 93307                     True                 Zebulon             60.00
#
#       state                        org_file  org_index letter  \
# 1        ct  Pierce_Certs_cleaned_2019.xlsx          0
# 2       NaN  Pierce_Certs_cleaned_2019.xlsx          1
# 3       NaN  Pierce_Certs_cleaned_2019.xlsx          2
# 4        nj  Pierce_Certs_cleaned_2019.xlsx          3
# 5        va  Pierce_Certs_cleaned_2019.xlsx          4
# ...     ...                             ...        ...    ...
# 93303    nh  Pierce_Certs_cleaned_2019.xlsx      93302
# 93304   NaN  Pierce_Certs_cleaned_2019.xlsx      93303
# 93305    ma  Pierce_Certs_cleaned_2019.xlsx      93304
# 93306    ma  Pierce_Certs_cleaned_2019.xlsx      93305
# 93307   NaN  Pierce_Certs_cleaned_2019.xlsx      93306
#
#       date of the certificate | month date of the certificate | day  \
# 1
# 2
# 3
# 4
# 5
# ...                               ...                           ...
# 93303
# 93304
# 93305
# 93306
# 93307
#
#       date of the certificate | year  ... to whom due | title.1  \
# 1                                     ...
# 2                                     ...
# 3                                     ...
# 4                                     ...
# 5                                     ...
# ...                              ...  ...                   ...
# 93303                                 ...
# 93304                                 ...
# 93305                                 ...
# 93306                                 ...
# 93307                                 ...
#
#       to whom due | first name.1 to whom due | last name.1  \
# 1
# 2
# 3
# 4
# 5
# ...                          ...                       ...
# 93303
# 93304
# 93305
# 93306
# 93307
#
#       time when the debt became due | day  \
# 1
# 2
# 3
# 4
# 5
# ...                                   ...
# 93303
# 93304
# 93305
# 93306
# 93307
#
#       time when the debt became due | month  \
# 1
# 2
# 3
# 4
# 5
# ...                                     ...
# 93303
# 93304
# 93305
# 93306
# 93307
#
#       time when the debt became due | year amount | 90th  \
# 1
# 2
# 3
# 4
# 5
# ...                                    ...           ...
# 93303
# 93304
# 93305
# 93306
# 93307
#
#       line strike through? | note notes line strike through? | yes?
# 1
# 2
# 3
# 4
# 5
# ...                           ...   ...                         ...
# 93303
# 93304
# 93305
# 93306
# 93307
#
# [93307 rows x 21 columns]

# %%
dataframes = [nh, nj, ny, ma, de, pierce]
david_debt = pd.read_csv("../../cleaning_CD/pre1790/data/agg_debt_david.csv")
david_debt = david_debt.drop(columns=["Unnamed: 0"])
print(david_debt.columns)
for df in dataframes:
    df.reindex(columns=david_debt.columns, fill_value="nan")
concatenated_df = pd.concat(dataframes)
final = pd.concat([concatenated_df, david_debt])
final
# Out:
# /var/folders/5f/ttydz5l94qz_x6kzy6q6_4_rnvbbsq/T/ipykernel_9051/2364292750.py:2: DtypeWarning: Columns (1,10,12,13,17,18,23,30) have mixed types. Specify dtype option on import or set low_memory=False.
#   david_debt = pd.read_csv("../../cleaning_CD/pre1790/clean_cols/agg_debt_david.csv")
# Index(['letter', 'date of the certificate | month',
#        'date of the certificate | day', 'date of the certificate | year',
#        'to whom due | first name', 'to whom due | last name',
#        'to whom due | title', 'to whom due | first name.1',
#        'to whom due | last name.1', 'to whom due | title.1',
#        'time when the debt became due | month',
#        'time when the debt became due | day',
#        'time when the debt became due | year', 'amount | dollars',
#        'amount | 90th', 'line strike through? | yes?',
#        'line strike through? | note', 'notes', 'state', 'org_file',
#        'org_index', 'amount | 10th', 'exchange', 'amount in specie | dollars',
#        'amount in specie | cents', 'amount | 8th', 'delivered | month',
#        'delivered | day', 'delivered | year', 'total dollars | notes',
#        'total dollars | notes.1'],
#       dtype='object')
#       letter date of the certificate | month date of the certificate | day  \
# 11         C                               8                            27
# 12         L                               8                            27
# 13         G                               8                            27
# 14         C                               9                             2
# 15         B                               9                             2
# ...      ...                             ...                           ...
# 94463      N                             5.0                          26.0
# 94464      P                             5.0                          28.0
# 94465      H                             4.0                          28.0
# 94466    NaN                             NaN                           NaN
# 94467    NaN                             NaN                           NaN
#
#       date of the certificate | year to whom due | first name  \
# 11                              1783                Elizabeth
# 12                              1783                   Joshua
# 13                              1783                   Joshua
# 14                              1783                 Phillips
# 15                              1783                  William
# ...                              ...                      ...
# 94463                         1789.0                  William
# 94464                         1789.0                    James
# 94465                         1789.0        Hoov and Harrison
# 94466                            NaN                      NaN
# 94467                            NaN                      NaN
#
#       to whom due | last name to whom due | title  \
# 11                     Lowell                 NaN
# 12                   Brackett                 Jun
# 13                   Brackett                 NaN
# 14                      White                 Esq
# 15                      White                 NaN
# ...                       ...                 ...
# 94463                   Smith                 NaN
# 94464                   Odell                 NaN
# 94465                     NaN                 NaN
# 94466                     NaN                 NaN
# 94467                     NaN                 NaN
#
#       time when the debt became due | month  \
# 11                                        4
# 12                                        4
# 13                                        4
# 14                                        4
# 15                                        4
# ...                                     ...
# 94463                                   6.0
# 94464                                   1.0
# 94465                                   6.0
# 94466                                   NaN
# 94467                                   NaN
#
#       time when the debt became due | day  \
# 11                                     16
# 12                                     16
# 13                                     16
# 14                                     16
# 15                                     16
# ...                                   ...
# 94463                                 1.0
# 94464                                 1.0
# 94465                                 1.0
# 94466                                 NaN
# 94467                                 NaN
#
#       time when the debt became due | year  ...  amount | 10th exchange  \
# 11                                    1782  ...            NaN      NaN
# 12                                    1782  ...            NaN      NaN
# 13                                    1782  ...            NaN      NaN
# 14                                    1782  ...            NaN      NaN
# 15                                    1782  ...            NaN      NaN
# ...                                    ...  ...            ...      ...
# 94463                               1780.0  ...            NaN      NaN
# 94464                               1778.0  ...            NaN      NaN
# 94465                               1780.0  ...            NaN      NaN
# 94466                                  NaN  ...            NaN      NaN
# 94467                                  NaN  ...            NaN      NaN
#
#       amount in specie | dollars amount in specie | cents amount | 8th  \
# 11                           NaN                      NaN          NaN
# 12                           NaN                      NaN          NaN
# 13                           NaN                      NaN          NaN
# 14                           NaN                      NaN          NaN
# 15                           NaN                      NaN          NaN
# ...                          ...                      ...          ...
# 94463                        NaN                      NaN          NaN
# 94464                        NaN                      NaN          NaN
# 94465                        NaN                      NaN          NaN
# 94466                        NaN                      NaN          NaN
# 94467                        NaN                      NaN          NaN
#
#       delivered | month delivered | day  delivered | year  \
# 11                  NaN             NaN               NaN
# 12                  NaN             NaN               NaN
# 13                  NaN             NaN               NaN
# 14                  NaN             NaN               NaN
# 15                  NaN             NaN               NaN
# ...                 ...             ...               ...
# 94463               NaN             NaN               NaN
# 94464               NaN             NaN               NaN
# 94465               NaN             NaN               NaN
# 94466               NaN             NaN               NaN
# 94467               NaN             NaN               NaN
#
#       total dollars | notes total dollars | notes.1
# 11                      NaN                     NaN
# 12                      NaN                     NaN
# 13                      NaN                     NaN
# 14                      NaN                     NaN
# 15                      NaN                     NaN
# ...                     ...                     ...
# 94463                   NaN                     NaN
# 94464              Reg 6768                     NaN
# 94465                   NaN                     NaN
# 94466                   NaN                     NaN
# 94467                   NaN                     NaN
#
# [203071 rows x 31 columns]

# %%
final.to_csv("../../cleaning_CD/pre1790/data/final_agg_debt.csv")
